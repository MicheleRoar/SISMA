# %%
import pandas as pd
import ast
from collections import Counter

# %%
artists = pd.read_csv("./data/archive/artists.csv")

# %%
artists.sort_values("popularity", ascending=False).head(50)
# Out:
#                             id   followers  \
# 144481  1uNFoZAHBGtllmzznpCI3s  44606973.0
# 126338  06HL4z0CvFAxyc27GXpf02  38869193.0
# 313676  3TVXtAsR1Inumwj472S9r4  54416812.0
# 115489  4q3ewBCX7sLwd24euuV69X  32244734.0
# 144484  3Nrfpe0tUJi4K4DXYWgMUX  31623813.0
# 144483  1Xyo4u8uXC1ZmMpatF05PJ  31308207.0
# 115490  4MCBfE4596Uoi2O4DtmEMz  16996777.0
# 115491  7iK8PXO48WeuP03g8YR51W   5001808.0
# 144487  6M2wZ9GZgrQXHCFfjv46we  24123468.0
# 144486  1vyhD5VmyZ7KMfW5gqLgo5  27286822.0
# 144485  66CXWjxzNUsdJxJ2JdwvnR  61301006.0
# 313813  0Y5tJX1MQlPlqiwlOH1tJY  16118616.0
# 144488  7dGJo4pcD2V6oG8kP0tJRR  43747833.0
# 117022  4r63FhuTkUYltbVAg5TQnk   6485079.0
# 145802  246dkjvS1zLTtiykXe5h60  32167665.0
# 126409  1i8SpTcr7yvPOmcqrbnVXY  27772492.0
# 144489  1mcTU81TzQhprhouKaTkpq   4438013.0
# 313701  5f7VJjfbwm532GiveGC0ZK   6789005.0
# 144490  0du5cEVh5yTK9QJze8zA0C  29899101.0
# 144138  6eUKZXaKkcviH0Ku9w2n3V  78900234.0
# 144139  5K4W6rqBFWDnAN6FQUkS6x  13713751.0
# ...

# %%
artists[artists.name.str.contains("Gigione", case=False, na=False)]
# Out:
#                            id  followers  \
# 28813  0CiNJ7w3zqBSlKbWSk0GvQ     6268.0
#
#                                                   genres     name  popularity
# 28813  ['canzone napoletana', 'classic italian folk p...  Gigione          33

# %%
artists[artists.genres.str.contains("italian adult pop")].sort_values(by="popularity", ascending=False)
# Out:
#                              id  followers  \
# 105777   0lAWpj5szCSwM4rUMHYmrr   933568.0
# 142338   2e4nwiX8ZCU09LGLOpeqTH  1719665.0
# 144333   61J0BktHv7PuP3tjTPYXSX  1437188.0
# 143056   3pgCLfNbw5ozIfoNsvDU7i  1579151.0
# 144325   5iot8OPcosJN9nCl7I5SdK  1473471.0
# ...                         ...        ...
# 223581   5g5ZJqGa6uwDbBnTRzhm6C      449.0
# 391279   1WeZ9BJEdKpFBGRRZ8aQU0      112.0
# 655647   3Z2BxUudYb90Gg7d3neiBc       38.0
# 1041238  173YtpxToZyeOHSt5JQoKh       25.0
# 860086   0bppg5MYeAyTonQCODBvjw       19.0
#
#                                                     genres              name  \
# 105777   ['indie rock italiano', 'italian adult pop', '...          Måneskin
# 142338   ['europop', 'italian adult pop', 'latin', 'lat...     Laura Pausini
# 144333                ['italian adult pop', 'mexican pop']   Eros Ramazzotti
# 143056                ['italian adult pop', 'italian pop']             Fedez
# ...

# %%
s = artists["name"].astype(str).str.lower()
print("drake hits:", s.str.contains("drake", regex=False).sum())
print("rihanna hits:", s.str.contains("rihanna", regex=False).sum())

# e controlla i primi match (per vedere se sono Nick Drake ecc.)
print(artists.loc[s.str.contains("rihanna", regex=False), "name"].head(20))
# Out:
# drake hits: 169
# rihanna hits: 2
# 313508            Rihanna
# 685489    Rihanna Johnson
# Name: name, dtype: object

# %%
tracks = pd.read_csv("./data/archive/tracks.csv")

# %%
tracks[tracks.artists.str.contains("Rihanna")]
# Out:
#                             id                           name  popularity  \
# 78366   4TsmezEQVSZNNPv5RJ65Ov                  Pon de Replay          80
# 79391   30cSNer6TV8x2utjULVeQ5                            SOS          73
# 79430   13xxBnXOuiBxVxJI458B0i                     Unfaithful          71
# 79799   0EIsxWGPSte4cAHZw5aXr4                        We Ride          63
# 81258   49FYlytm3dAAraYgpoJZux                       Umbrella          83
# ...                        ...                            ...         ...
# 574335  2vDZwEDKyiaKOsvEQbaRcQ  P.S. (I'm Still Not Over You)          47
# 574548  7F0429jN4uWI1QBFJIew0e           Hate That I Love You          43
# 574677  0a1vOhpBblkpapGPICEngd                       Umbrella          37
# 583535  6BZJSdeVicl1LEtWUQKP4o            Where Have You Been          59
# 583652  7drd8T07dm62NkcYESlVhu                 Talk That Talk          53
#
#         duration_ms  explicit               artists  \
# ...
